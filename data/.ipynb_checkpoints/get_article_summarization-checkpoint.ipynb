# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
#   Using cached pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pf = pd.read_csv("get_article_summarization.csv")

# %%
pf.head()
# Out:
#    bookmarked                                    id                 timestamp  \
# 0       False  45502b49-a970-4b59-80ee-9ed35d10e685  2024-09-27T09:28:34.920Z
# 1       False  a3ad8221-8a00-4702-bce5-586ad467ae49  2024-09-27T09:28:09.924Z
# 2       False  0172b449-8341-466b-9292-112cd2e26d9b  2024-09-27T09:27:51.943Z
# 3       False  8d771407-1901-4677-9d2b-f590e2695c69  2024-09-26T15:29:36.807Z
# 4       False  f721ca3d-7a7c-4a8e-bd18-34280669e338  2024-09-26T15:29:19.501Z
#
#                         name  userId    level  observationCount  latency  \
# 0  get_article_summarization     NaN  DEFAULT                 2    0.956
# 1  get_article_summarization     NaN  DEFAULT                 2    1.020
# 2  get_article_summarization     NaN  DEFAULT                 2    1.550
# 3  get_article_summarization     NaN  DEFAULT                 2    2.336
# 4  get_article_summarization     NaN  DEFAULT                 2    0.975
#
# ...

# %%
import json
input = json.loads(pf.iloc[10].input)
from pprint import pprint
pprint(input)
pf.iloc[10].output
# Out:
# {'args': ['Add AI-powered search to your graph with Hypermode →\n'
#           'Product\n'
#           'Solutions\n'
#           'Docs\n'
#           'Pricing\n'
#           'Resources\n'
#           'Sign In\n'
#           'Contact Us\n'
#           'DOCS\n'
#           'TUTORIALS\n'
#           'Dgraph version:\n'
#           'v24.0 (latest)\n'
#           'v23.1\n'
#           'v23.0\n'
#           'v22.0\n'
#           'v21.03\n'
#           'Home\n'
#           'Dgraph Overview\n'
#           'GraphQL API\n'
#           'Dgraph Query Language\n'
#           'Quick Start\n'
#           'DQL Syntax\n'
#           'Dgraph types schema\n'
#           'Predicate indexes\n'
#           'Mutations\n'
#           'Query Language\n'
#           'Client Libraries\n'
#           'DQL: Tips and Tricks\n'
#           'GraphQL - DQL interoperability\n'
#           'Ratel UI\n'
#           'Data migration\n'
#           'Dgraph Cloud\n'
#           'Self-managed cluster\n'
# ...
